# %%
from urllib import request
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
#Gerekli Listeler
url_list=[]
prices_list=[]
propTitles=[]
propValues=[]

# Değerlerin çekilmesi
for i in range(1, 30):  # gidilecek sayfa sayisi
    url = "https://www.trendyol.com/sr?q=telefon&qt=telefon&st=telefon&os=" + str(i)
    r = requests.get(url)  # elde edilen url'ye bağlanma isteği
    source = BeautifulSoup(r.content, "lxml")  # verilerin çekilme işlemi

    urls = source.find_all("div", attrs={"p-card-chldrn-cntnr"})
    for url in urls:
        url_phone = "https://www.trendyol.com/" + url.a.get("href")
        url_list.append(url_phone)  # linkler listeye kaydediliyor
        print(url_phone)

        # Bu kısım döngü içinde olmalı, aksi halde en son url_phone değeri kullanılır
        r_phone = requests.get(url_phone)  # linke istek atiliyor
        source_phone = BeautifulSoup(r_phone.content, "lxml")  # lxml formatinda veri cekiliyor
        
        prices = source_phone.find("span", attrs={"class": "prc-dsc"})
        for price in prices:
            prices_list.append(price.text)
            print(price.text)

        
        properties = source_phone.find_all("li", attrs={"class": "attribute-item"})
        for prop in properties:
            prop_title = prop.find("span", attrs={"class": "attribute-label"}).text
            prop_value = prop.find("span", attrs={"class": "attribute-value"}).text
            propTitles.append(prop_title)
            propValues.append(prop_value)

      

print(str(len(url_list)) + " adet link bulundu.")
print(str(len(prices_list)) + " adet fiyat bulundu.")
print(str(len(propTitles)) + " adet ozellik basligi bulundu.")
print(str(len(propValues)) + " adet ozellik verisi bulundu.")
# Out:
# https://www.trendyol.com//xiaomi/redmi-12-128-gb-8-gb-ram-gumus-cep-telefonu-xiaomi-turkiye-garantili-p-765278800?boutiqueId=623361&merchantId=968
# 7.549 TL
# https://www.trendyol.com//apple/iphone-12-128-gb-beyaz-cep-telefonu-aksesuarsiz-kutu-apple-turkiye-garantili-p-65277274?boutiqueId=623361&merchantId=968&advertItems=
# 28.499 TL
# https://www.trendyol.com//reeder/s19-max-pro-4gb-128-gb-siyah-cep-telefonu-reeder-turkiye-garantili-p-411322828?boutiqueId=61&merchantId=110032
# 3.089 TL
# https://www.trendyol.com//apple/iphone-15-128-gb-pembe-p-762254841?boutiqueId=623361&merchantId=968&advertItems=
# 51.299 TL
# https://www.trendyol.com//xiaomi/redmi-12c-128-gb-4-gb-ram-gri-cep-telefonu-xiaomi-turkiye-garantili-p-666265944?boutiqueId=623361&merchantId=968
# 5.149 TL
# https://www.trendyol.com//apple/iphone-12-128-gb-mor-cep-telefonu-aksesuarsiz-kutu-apple-turkiye-garantili-p-103752856?boutiqueId=623427&merchantId=968&advertItems=
# 28.499 TL
# https://www.trendyol.com//reeder/s19-max-pro-4gb-128-gb-altin-cep-telefonu-reeder-turkiye-garantili-p-411319447?boutiqueId=61&merchantId=105306
# 2.955 TL
# https://www.trendyol.com//apple/iphone-15-plus-128-gb-siyah-p-762254831?boutiqueId=623361&merchantId=968&advertItems=
# 56.399 TL
# https://www.trendyol.com//xiaomi/redmi-12-128-gb-8-gb-ram-siyah-cep-telefonu-xiaomi-turkiye-garantili-p-770302563?boutiqueId=623361&merchantId=968
# 7.549 TL
# https://www.trendyol.com//apple/iphone-12-128-gb-siyah-cep-telefonu-aksesuarsiz-kutu-apple-turkiye-garantili-p-313989390?boutiqueId=623361&merchantId=968&advertItems=
# 28.499 TL
# %%
#url ve fiyat bilgilerini iceren yeni dataframe
df=pd.DataFrame(columns=columns)
df["url"]=url_list
df["price"]=prices_list

# %%
#yeni dataframe'nin gosterimi
df.head()
# Out:
#   Cep Telefonu Modeli Dahili Hafıza Ekran Boyutu Garanti Tipi  \
# 0                 NaN           NaN          NaN          NaN
# 1                 NaN           NaN          NaN          NaN
# 2                 NaN           NaN          NaN          NaN
# 3                 NaN           NaN          NaN          NaN
# 4                 NaN           NaN          NaN          NaN
#
#   Kamera Çözünürlüğü Mobil Bağlantı Hızı Pil Gücü (mAh) RAM Kapasitesi  \
# 0                NaN                 NaN            NaN            NaN
# 1                NaN                 NaN            NaN            NaN
# 2                NaN                 NaN            NaN            NaN
# 3                NaN                 NaN            NaN            NaN
# 4                NaN                 NaN            NaN            NaN
#
#   Ön Kamera Çözünürlüğü                                                url  \
# 0                   NaN  https://www.trendyol.com//xiaomi/redmi-12-128-...
# 1                   NaN  https://www.trendyol.com//apple/iphone-12-128-...
# 2                   NaN  https://www.trendyol.com//reeder/s19-max-pro-4...
# 3                   NaN  https://www.trendyol.com//apple/iphone-15-128-...
# 4                   NaN  https://www.trendyol.com//xiaomi/redmi-12c-128...
#
#        price
# 0   7.549 TL
# 1  28.499 TL
# 2   3.089 TL
# 3  51.299 TL
# 4   5.149 TL

# %%
for i in range(0, len(df)):
    url = df['url'].loc[i]
    r = requests.get(url)
    source = BeautifulSoup(r.content, "lxml")

    properties = source.find_all("li", attrs={"class": "attribute-item"})
    for prop in properties:
        prop_title = prop.find("span", attrs={"class": "attribute-label"}).text
        prop_value = prop.find("span", attrs={"class": "attribute-value"}).text

        # Her bir özelliği DataFrame'e ekleyin
        df.loc[i, prop_title] = prop_value

# %%
df.head()
# Out:
#   Cep Telefonu Modeli Dahili Hafıza Ekran Boyutu              Garanti Tipi  \
# 0                 NaN        128 GB    6 - 8 inç  Xiaomi Türkiye Garantili
# 1           iPhone 12        128 GB      6,1 inç   Apple Türkiye Garantili
# 2  Reeder S19 Max Pro        128 GB      6,7 inç           Genpa Garantili
# 3           iPhone 15        128 GB      6,1 inç   Apple Türkiye Garantili
# 4           Redmi 12C        128 GB    6 - 8 inç  Xiaomi Türkiye Garantili
#
#     Kamera Çözünürlüğü Mobil Bağlantı Hızı Pil Gücü (mAh) RAM Kapasitesi  \
# 0  50 MP + 8 MP + 2 MP                4.5G           5000           8 GB
# 1           10 - 15 MP                4.5G           2815           4 GB
# 2                  NaN                4.5G   5000 ve üstü           4 GB
# 3        20 MP ve üstü                  5G    3000 - 4000           6 GB
# 4        20 MP ve üstü                4.5G    4000 - 5000           4 GB
#
#   Ön Kamera Çözünürlüğü                                                url  \
# 0                  8 MP  https://www.trendyol.com//xiaomi/redmi-12-128-...
# 1                   NaN  https://www.trendyol.com//apple/iphone-12-128-...
# 2            14 - 20 MP  https://www.trendyol.com//reeder/s19-max-pro-4...
# 3                   NaN  https://www.trendyol.com//apple/iphone-15-128-...
# 4                   NaN  https://www.trendyol.com//xiaomi/redmi-12c-128...
#
#        price
# 0   7.549 TL
# 1  28.499 TL
# 2   3.089 TL
# 3  51.299 TL
# 4   5.149 TL

# %%
# CSV dosyasına yazma
df.to_csv(r"C:\Users\hakan\source\repos\machine_learning\phone_data.csv", index=False, encoding="utf-8")
